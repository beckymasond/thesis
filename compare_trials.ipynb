# %%
from IPython.display import IFrame, SVG, display
# %matplotlib inline
import geopandas as gp
from pylab import rcParams
rcParams['figure.figsize'] = 20,20  #set the default map size

# %%
IFrame('force/force.html', width=950, height=700)
# Out:
#         <iframe
#             width="950"
#             height="700"
#             src="force/force.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
display(SVG('hist_19740.svg'))

# %%
display(SVG('hist_38900.svg'))

# %%
display(SVG('degHist_19740.svg'))

# %%
display(SVG('degHist_38900.svg'))

# %%
IFrame('force/force60.html', width=950, height=700)
# Out:
#         <iframe
#             width="950"
#             height="700"
#             src="force/force60.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Map of Denver MSA
denver = gp.read_file('19740/19740_hous_tracts.shp')
denver['constant'] = 1
p = denver.plot('constant', alpha=0.5, cmap='summer')
p.axis('off')
p.plot()
# Out:
# []

# %% [markdown]
# The second map, below, shows the tracts that appear in the network graph of >60% frequency. Over two-thirds of the tracts are part of one of these high frequency pairs, a more promising outcome for identifying stable groups. In other words, although most pairs are relatively rare, most tracts are also in pairs that occur frequently.

# %%
freq60 = gp.read_file('freq60.shp')
freq60['constant'] = 1
p = freq60.plot('constant', alpha=0.5, cmap='winter')
p.axis('off')
p.plot()
# Out:
# []

# %% [markdown]
# By isolating the pairings that occur often, a new story emerges that suggests despite a large number of tract pairs that are noisy or somewhat random, many tracts have at least a modest level of stability. Examining the very high frequency tracts, >90% occurrence, further reveals areas of high stability, though most of these highly stable groups contain only two tracts.

# %%
IFrame('force/force90.html', width=950, height=700)
# Out:
#         <iframe
#             width="950"
#             height="700"
#             src="force/force90.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Roughly 1/6 of tracts are involved in a very high frequency pair
freq90 = gp.read_file('freq90.shp')
freq90['constant'] = 1
p = freq90.plot('constant', alpha=0.5, cmap='spring')
p.axis('off')
p.plot()
# Out:
# []

# %% [markdown]
# **Challenges**
# - Methods to examine group stability/Testing variations in the output
# - Matching stable groups to real or perceived neighborhood boundaries
# - If the regionalization algorithm's output isn't related to any regions informed by other measures (physical, perceived, etc.), is there something to say about them or their patterns?

# %% [markdown]
# **Future plans**
#
# I don't plan on continuing on to a Ph.D. program at this time. After graduation, I'd love to find an analytical role that addresses issues relevant to public resource allocation, which would most likely be in a government or a non-profit setting. Realistically, those jobs are scarce and difficult to obtain, so I'll also be looking at roles in data analysis and/or product management in the technology sector.
